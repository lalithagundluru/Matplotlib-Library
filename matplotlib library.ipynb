# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# WARNING: You are using pip version 22.0.4; however, version 22.1.1 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib 
import numpy as np
import pandas as pd

# %%
from matplotlib import pyplot as plt

# %%
x=[1,2,3]
y=[2,3,4]
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.title('information')
plt.xlabel('xaxis')
plt.ylabel('yaxis')
plt.show()

# %%
xpoints=np.array([0,6])
ypoints=np.array([0,9])
plt.plot(xpoints,ypoints)
plt.show()

# %%
xpoints=np.array([0,6])
ypoints=np.array([0,9])
plt.plot(xpoints,ypoints,"o")
plt.show()

# %%
x=np.arange(10)
y=np.arange(10)
plt.title('information')
plt.xlabel('xaxis')
plt.ylabel('yaxis')
plt.plot(x,y,'o')
plt.show()
#plt.plot(x,y)
plt.grid()

# %%
plt.plot(x,y)

# %%
plt.plot(x,y)
plt.grid()

# %%
plt.plot(x,y,marker='D')

# %%
plt.plot(x,y,marker='s')

# %%
plt.plot(x,y,marker='h')

# %%
plt.plot(x,y,marker='o')

# %%
plt.plot(x,y,marker='o',ms=10,mec='b',mfc="r")

# %%
plt.plot(x,y,marker='D',ms=5,mec='m',mfc="c")

# %%
plt.plot(x,y,linestyle='dashed')

# %%
plt.plot(x,y,linestyle='dotted')

# %%
plt.plot(x,y,linestyle='dashdot')

# %%
plt.plot(x,y,linestyle='solid')

# %%
plt.plot(x,y,linewidth=5)

# %%
x=np.array([1,2,3])
y=np.array([3,4,9])
print(x)
print(y)
#plt.subplot(1,2,1)
plt.plot(x,y)
plt.show()
# Out:
# [1 2 3]
# [3 4 9]

# %%
a=np.array([2,9,6])
b=np.array([1,8,4])
plt.plot(a,b,linestyle='dotted')
#plt.subplot(1,2,2)
plt.show()

# %%
x=np.array([1,2,3])
y=np.array([3,4,9])
print(x)
print(y)
plt.subplot(2,1,1)
plt.plot(x,y)
plt.show()
a=np.array([2,9,6])
b=np.array([1,8,4])
plt.plot(a,b,linestyle='dotted')
plt.subplot(2,1,2)
plt.show()
# Out:
# [1 2 3]
# [3 4 9]

# %%
activities=(['sports','phone','friends','money','online','club','tv'])
frequency=([45,56,43,56,78,12,32])
plt.barh(activities,frequency,color='c')
plt.title('activity chart')
plt.xlabel('activities')
plt.ylabel('frequency')
plt.show()

# %%
activities=(['sports','phone','friends','money','online','club','tv'])
frequency=([45,56,43,56,78,12,32])
plt.bar(activities,frequency,color='c')
plt.title('activity chart')
plt.xlabel('activities')
plt.ylabel('frequency')
plt.show()
